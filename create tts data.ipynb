# %%
pip install google-cloud-texttospeech

# %%
# !pip install pandas openpyxl

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
from google.cloud import texttospeech
import pandas as pd

# Google Cloud 인증 파일 업로드
from google.colab import files
uploaded = files.upload()

# 업로드한 인증 파일 경로 설정 (업로드한 파일명으로 변경)
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = list(uploaded.keys())[0]

# TTS 클라이언트 초기화
client = texttospeech.TextToSpeechClient()

# 이미 업로드된 엑셀 파일 경로 (여기서는 /mnt/data/formatted_top_101_scripts.xlsx로 설정)
file_path = '/content/drive/MyDrive/1.xlsx'
file_path1 = '/content/drive/MyDrive/Final_Formatted_ALL.xlsx'
# Out:
#      <input type="file" id="files-38ef18c5-e105-469c-a20a-d9b5675eefac" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-38ef18c5-e105-469c-a20a-d9b5675eefac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Excel 파일 읽기
df = pd.read_excel(file_path)
output_dir = 'tts_outputs_final'
os.makedirs(output_dir, exist_ok=True)

for index, row in df.iterrows():
    code = row['파일']
    content = row['내용']

    # TTS 요청 생성
    synthesis_input = texttospeech.SynthesisInput(text=content)
    voice = texttospeech.VoiceSelectionParams(language_code="ko-KR", ssml_gender=texttospeech.SsmlVoiceGender.NEUTRAL)
    audio_config = texttospeech.AudioConfig(audio_encoding=texttospeech.AudioEncoding.LINEAR16)  # WAV 형식으로 설정

    # TTS 요청 실행
    response = client.synthesize_speech(input=synthesis_input, voice=voice, audio_config=audio_config)

    # 오디오 파일 저장
    output_file = os.path.join(output_dir, f"{code}.wav")
    with open(output_file, "wb") as out:
        out.write(response.audio_content)
        print(f'Audio content written to file "{output_file}"')

print("All TTS files have been created.")

# 생성된 파일을 zip으로 압축하여 다운로드
import shutil
shutil.make_archive(output_dir, 'zip', output_dir)

# 압축된 파일 다운로드
files.download(f'{output_dir}.zip')
# Out:
# Audio content written to file "tts_outputs_final/E0001.wav"
# All TTS files have been created.

# %%
df = pd.read_excel(file_path1)
output_dir = 'tts_outputs1'
os.makedirs(output_dir, exist_ok=True)

for index, row in df.iterrows():
    code = row['파일']
    content = row['내용']

    # TTS 요청 생성
    synthesis_input = texttospeech.SynthesisInput(text=content)
    voice = texttospeech.VoiceSelectionParams(language_code="ko-KR", ssml_gender=texttospeech.SsmlVoiceGender.NEUTRAL)
    audio_config = texttospeech.AudioConfig(audio_encoding=texttospeech.AudioEncoding.LINEAR16)  # WAV 형식으로 설정

    # TTS 요청 실행
    response = client.synthesize_speech(input=synthesis_input, voice=voice, audio_config=audio_config)

    # 오디오 파일 저장
    output_file = os.path.join(output_dir, f"{code}.wav")
    with open(output_file, "wb") as out:
        out.write(response.audio_content)
        print(f'Audio content written to file "{output_file}"')

print("All TTS files have been created.")

# 생성된 파일을 zip으로 압축하여 다운로드
import shutil
shutil.make_archive(output_dir, 'zip', output_dir)

# 압축된 파일 다운로드
files.download(f'{output_dir}.zip')
# Out:
# Audio content written to file "tts_outputs1/E00688.wav"
# Audio content written to file "tts_outputs1/E02887.wav"
# Audio content written to file "tts_outputs1/E01401.wav"
# Audio content written to file "tts_outputs1/E02342.wav"
# Audio content written to file "tts_outputs1/E01119.wav"
# Audio content written to file "tts_outputs1/E01874.wav"
# Audio content written to file "tts_outputs1/E02854.wav"
# Audio content written to file "tts_outputs1/E02500.wav"
# Audio content written to file "tts_outputs1/E00719.wav"
# Audio content written to file "tts_outputs1/E02551.wav"
# Audio content written to file "tts_outputs1/E02711.wav"
# Audio content written to file "tts_outputs1/E01418.wav"
# Audio content written to file "tts_outputs1/E00240.wav"
# Audio content written to file "tts_outputs1/E02716.wav"
# Audio content written to file "tts_outputs1/E01535.wav"
# Audio content written to file "tts_outputs1/E01445.wav"
# Audio content written to file "tts_outputs1/E00690.wav"
# ...
